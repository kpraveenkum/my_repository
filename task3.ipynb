# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
import pickle 
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
#DATADIR = "PetImages"
#CATEGORIES = ["Cat", "Dog"]
#IMG_SIZE = 100

#data = []

#for category in CATEGORIES:
 #   path = os.path.join(DATADIR, category)
  #  class_num = CATEGORIES.index(category)
   # for img in os.listdir(path):
    #    try:
     #       img_path = os.path.join(path, img)
      #      img_array = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

       #     if img_array is None:
        #        print(f⚠️ Skipped invalid image: {img_path}")
         #       continue
                
          #  resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
           # data.append((resized.flatten(), class_num))

#        except:
 #           pass

#with open("data1.pickel", "wb") as f:
 #   pickle.dump(data, f)
  #  pick_in.close()
pick_in = open('data1.pickel','rb')
data=pickle.load(pick_in)
pick_in.close()
random.shuffle(data)
features=[]
labels=[]
for feature,label in data:
    features.append(feature)
    labels.append(label)
features = np.array(features, dtype='float32') / 255.0
labels = np.array(labels, dtype='int')
#print("Unique labels and counts:", np.unique(labels, return_counts=True))
xtrain, xtest, ytrain, ytest = train_test_split(
    features, labels, test_size=0.35, stratify=labels
)
#print("Train labels distribution:", np.unique(ytrain, return_counts=True))
#print("Test labels distribution:", np.unique(ytest, return_counts=True))

model=SVC(C=1,kernel='poly',gamma='auto')
#print("xtrain shape:", xtrain.shape)
#print("ytrain shape:", ytrain.shape)
model.fit(xtrain,ytrain)

pick = open('medel.sav','wb')
model = pickle.dump(model,pick)
pick.close()

#pre=model.predict(xtest)
#acc= model.score(xtest,ytest)
#categories = ['Cat', 'Dog'] 
#print("accuracy : ", acc)
#print("prediction : " , categories[pre[0]])
#mypet = xtest[0].reshape(50,50)
#plt.imshow(mypet,cmap='gray')
#plt.show()
